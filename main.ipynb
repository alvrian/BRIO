# %% [markdown]
# # BRIO: Bringing Order to Abstractive Summarization
# **ACL 2022** | [Paper](https://arxiv.org/abs/2203.16804) | [GitHub](https://github.com/yixinl7/BRIO)
#
# This notebook provides a complete step-by-step guide to:
# 1. **Setup** – Install dependencies & prepare workspace
# 2. **Data Preparation** – Download preprocessed CNNDM data
# 3. **Candidate Generation** – Generate diverse candidate summaries
# 4. **Preprocessing** – Score candidates with ROUGE & create JSON files
# 5. **Training** – Train BRIO with contrastive + MLE loss
# 6. **Evaluation** – Evaluate as generator & scorer/reranker
# 7. **Quick Demo** – Use pretrained BRIO from HuggingFace

# %% [markdown]
# ---
# ## 1. Environment Setup

# %%
# !git clone https://github.com/alvrian/BRIO.git
# %cd BRIO
# Out:
# Cloning into 'BRIO'...
# remote: Enumerating objects: 138, done.
# remote: Counting objects: 100% (59/59), done.
# remote: Compressing objects: 100% (30/30), done.
# remote: Total 138 (delta 44), reused 35 (delta 29), pack-reused 79 (from 1)
# Receiving objects: 100% (138/138), 7.59 MiB | 21.30 MiB/s, done.
# Resolving deltas: 100% (67/67), done.
# /content/BRIO

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install -q condacolab
import condacolab
condacolab.install()
# Out:
# 📢 Announcement 📢
# condacolab==0.2 will be released soon! Try it with:
#
#     !pip install -q https://github.com/conda-incubator/condacolab/archive/main.zip
#     import condacolab
#     condacolab.install()
#
# 0.2.x introduces a new installation method based on Pixi, with customizable Python versions.
# This may be breaking for your workflow. If that's the case, please report it at
# https://github.com/conda-incubator/condacolab and pin your `pip install` command to
# condacolab==0.1 as a workaround.
#
# ⏬ Downloading https://github.com/conda-forge/miniforge/releases/download/26.3.2-3/Miniforge3-26.3.2-3-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:00:11
# 🔁 Restarting kernel...

# %%
# !cp /content/drive/MyDrive/Dataset/cnndm.zip .
# !unzip -q cnndm.zip
# %cd /content/BRIO

# %%
! conda create --name env --file spec-file.txt
# !source activate env && pip install -r requirements.txt
! git clone https://github.com/neulab/compare-mt.git
# !cd compare-mt && pip install -r requirements.txt && python setup.py install
# Out:
# Streaming output truncated to the last 5000 lines.
#
#
#
#
#
#
# libiconv-1.16        | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libuv-1.42.0         | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
# ca-certificates-2021 | :  92% 0.9203912674058522/1 [00:00<00:00,  9.13it/s]
#
# ca-certificates-2021 | : 100% 1.0/1 [00:00<00:00,  9.13it/s]
#
# ca-certificates-2021 | : 100% 1.0/1 [00:00<00:00,  9.13it/s]
# blas-1.0             | : 100% 1.0/1 [00:00<00:00,  4.44it/s]
# _libgcc_mutex-0.1    | : 100% 1.0/1 [00:00<00:00,  4.34it/s]
#
#
# intel-openmp-2021.3. | :   1% 0.011373204801680435/1 [00:00<00:19, 20.21s/it]
# _libgcc_mutex-0.1    | : 100% 1.0/1 [00:00<00:00,  4.34it/s]
#
#
#
#
#
# libgomp-9.3.0        | :   5% 0.051509378202830754/1 [00:00<00:04,  4.87s/it]
#
#
# intel-openmp-2021.3. | : 100% 1.0/1 [00:00<00:00, 20.21s/it]
#
#
#
#
#
# libgomp-9.3.0        | : 100% 1.0/1 [00:00<00:00,  4.87s/it]
#
#
#
# ld_impl_linux-64-2.3 | :   3% 0.027299614266314536/1 [00:00<00:09, 10.22s/it]
#
#
#
#
#
#
#
# _openmp_mutex-4.5    | :  74% 0.7391833972479134/1 [00:00<00:00,  2.52it/s]
#
#
#
#
# libstdcxx-ng-9.3.0   | :   1% 0.005042836718770439/1 [00:00<00:59, 59.37s/it]
#
#
#
#
#
#
#
# _openmp_mutex-4.5    | : 100% 1.0/1 [00:00<00:00,  2.52it/s]
#
#
#
# ld_impl_linux-64-2.3 | : 100% 1.0/1 [00:00<00:00, 10.22s/it]
#
#
#
#
#
#
#
#
# libgcc-ng-9.3.0      | :   0% 0.003253736862372134/1 [00:00<01:36, 96.85s/it]
#
#
#
#
#
# libgomp-9.3.0        | : 100% 1.0/1 [00:00<00:00,  4.87s/it]
#
#
#
#
#
#
# mkl-2021.3.0         | :   0% 0.00011065242687537004/1 [00:00<51:58, 3119.16s/it]
#
#
#
#
# libstdcxx-ng-9.3.0   | : 100% 1.0/1 [00:00<00:00, 59.37s/it]
#
#
# intel-openmp-2021.3. | : 100% 1.0/1 [00:00<00:00,  2.82it/s]
#
#
# intel-openmp-2021.3. | : 100% 1.0/1 [00:00<00:00,  2.82it/s]
#
#
#
#
#
#
#
#
# libgcc-ng-9.3.0      | :  70% 0.7028071622723809/1 [00:00<00:00,  2.19it/s]
#
#
#
#
#
#
#
#
#
#
#
# giflib-5.2.1         | :  21% 0.2066000025219727/1 [00:00<00:01,  2.05s/it]
#
#
#
#
#
#
#
#
#
# bzip2-1.0.8          | :   3% 0.03305318286173101/1 [00:00<00:12, 12.92s/it]
#
#
#
#
#
#
#
#
#
#
#
# giflib-5.2.1         | : 100% 1.0/1 [00:00<00:00,  2.05s/it]
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.1.1   | :   0% 1.2681904991056594e-05/1 [00:00<9:41:12, 34873.01s/it]
#
#
#
#
#
#
# mkl-2021.3.0         | :   3% 0.02500744847383363/1 [00:00<00:13, 13.68s/it]
#
#
#
#
#
#
#
# _openmp_mutex-4.5    | : 100% 1.0/1 [00:00<00:00,  2.16it/s]
#
#
#
#
#
#
#
# _openmp_mutex-4.5    | : 100% 1.0/1 [00:00<00:00,  2.16it/s]
#
#
#
#
#
#
#
#
#
# bzip2-1.0.8          | : 100% 1.0/1 [00:00<00:00, 12.92s/it]
#
#
#
#
#
#
#
#
# libgcc-ng-9.3.0      | : 100% 1.0/1 [00:00<00:00,  2.19it/s]
#
#
#
#
#
#
#
#
#
#
#
#
# gmp-6.2.1            | :   2% 0.019840539414665338/1 [00:00<00:23, 23.84s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# jpeg-9b              | :   7% 0.07470499188385708/1 [00:00<00:06,  6.64s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# gmp-6.2.1            | : 100% 1.0/1 [00:00<00:00, 23.84s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# jpeg-9b              | : 100% 1.0/1 [00:00<00:00,  6.64s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# lame-3.100           | :   3% 0.03224466902177656/1 [00:00<00:16, 16.71s/it]
#
#
#
#
#
#
# mkl-2021.3.0         | :   6% 0.06074818235457815/1 [00:00<00:05,  6.38s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libffi-3.3           | :  32% 0.3178705158799449/1 [00:00<00:01,  1.71s/it]
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.1.1   | :   0% 0.0007355504894812825/1 [00:00<09:27, 568.02s/it]
#
#
#
# ld_impl_linux-64-2.3 | : 100% 1.0/1 [00:00<00:00,  2.10it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libffi-3.3           | : 100% 1.0/1 [00:00<00:00,  1.71s/it]
#
#
#
# ld_impl_linux-64-2.3 | : 100% 1.0/1 [00:00<00:00,  2.10it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# lame-3.100           | : 100% 1.0/1 [00:00<00:00, 16.71s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libiconv-1.16        | :   1% 0.011550530398043516/1 [00:00<00:49, 50.39s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libiconv-1.16        | : 100% 1.0/1 [00:00<00:00, 50.39s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libuv-1.42.0         | :   2% 0.01511075285378705/1 [00:00<00:44, 45.52s/it]
#
#
#
#
#
#
#
#
#
#
#
# giflib-5.2.1         | : 100% 1.0/1 [00:00<00:00,  1.64it/s]
#
#
#
#
#
#
#
#
#
#
#
# giflib-5.2.1         | : 100% 1.0/1 [00:00<00:00,  1.64it/s]
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.1.1   | :   0% 0.0011794171641682633/1 [00:00<07:54, 474.70s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libuv-1.42.0         | : 100% 1.0/1 [00:00<00:00, 45.52s/it]
#
#
#
#
#
#
# mkl-2021.3.0         | :   8% 0.08498106384028419/1 [00:00<00:06,  6.74s/it]
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.1.1   | :   0% 0.0016106019338641875/1 [00:00<06:19, 380.15s/it]
#
#
#
#
# libstdcxx-ng-9.3.0   | : 100% 1.0/1 [00:00<00:00,  1.33it/s]
#
#
#
#
# libstdcxx-ng-9.3.0   | : 100% 1.0/1 [00:00<00:00,  1.33it/s]
#
#
#
#
#
#
#
#
#
# bzip2-1.0.8          | : 100% 1.0/1 [00:00<00:00,  1.27it/s]
#
#
#
#
#
#
#
#
#
# bzip2-1.0.8          | : 100% 1.0/1 [00:00<00:00,  1.27it/s]
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.1.1   | :   0% 0.0020417867035601115/1 [00:00<05:27, 327.83s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# jpeg-9b              | : 100% 1.0/1 [00:00<00:00,  1.21it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
# jpeg-9b              | : 100% 1.0/1 [00:00<00:00,  1.21it/s]
#
#
#
#
#
#
# mkl-2021.3.0         | :  11% 0.10511980553160154/1 [00:00<00:07,  8.67s/it]
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.1.1   | :   0% 0.002878792432969847/1 [00:01<03:43, 223.92s/it]
#
#
#
#
#
#
# mkl-2021.3.0         | :  12% 0.12083245014790409/1 [00:01<00:08,  9.12s/it]
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.1.1   | :   0% 0.0034241143475852802/1 [00:01<03:57, 238.15s/it]
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.1.1   | :   0% 0
/it]
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.1.1   | :  95% 0.9543133505770087/1 [00:40<00:01, 38.03s/it]
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.1.1   | :  96% 0.9574330992048087/1 [00:40<00:01, 36.56s/it]
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.1.1   | :  96% 0.9605528478326085/1 [00:40<00:01, 35.39s/it]
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.1.1   | :  96% 0.9634189583605873/1 [00:40<00:01, 36.77s/it]
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.1.1   | :  97% 0.9661709317436467/1 [00:40<00:01, 38.47s/it]
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.1.1   | :  97% 0.9687960860767953/1 [00:40<00:01, 41.94s/it]
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.1.1   | :  97% 0.9721567908994253/1 [00:40<00:01, 37.93s/it]
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.1.1   | :  97% 0.9748580366625204/1 [00:41<00:01, 41.11s/it]
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.1.1   | :  98% 0.9777241471904992/1 [00:41<00:00, 39.29s/it]
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.1.1   | :  98% 0.9813765358279235/1 [00:41<00:00, 35.15s/it]
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.1.1   | :  98% 0.9843567835008218/1 [00:41<00:00, 34.79s/it]
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.1.1   | :  99% 0.9872863035537559/1 [00:41<00:00, 39.85s/it]
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.1.1   | :  99% 0.9912684217209476/1 [00:41<00:00, 34.67s/it]
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.1.1   | :  99% 0.994286715108819/1 [00:41<00:00, 46.08s/it]
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.1.1   | : 100% 0.9982434694660287/1 [00:41<00:00, 38.92s/it]
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.1.1   | : 100% 1.0/1 [00:41<00:00, 38.92s/it]
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.1.1   | : 100% 1.0/1 [05:07<00:00, 38.92s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Downloading and Extracting Packages:
#
#
# ## Package Plan ##
#
#   environment location: /usr/local/envs/env
#
#   added / updated specs:
#     - conda-forge/linux-64::bzip2==1.0.8=h7f98852_4
#     - conda-forge/linux-64::ca-certificates==2021.10.8=ha878542_0
#     - conda-forge/linux-64::certifi==2021.10.8=py38h578d9bd_0
#     - conda-forge/linux-64::cudatoolkit==11.1.1=h6406543_8
#     - conda-forge/linux-64::freetype==2.10.4=h0708190_1
#     - conda-forge/linux-64::giflib==5.2.1=h36c2ea0_2
#     - conda-forge/linux-64::gmp==6.2.1=h58526e2_0
#     - conda-forge/linux-64::gnutls==3.6.13=h85f3911_1
#     - conda-forge/linux-64::lame==3.100=h7f98852_1001
#     - conda-forge/linux-64::libiconv==1.16=h516909a_0
#     - conda-forge/linux-64::libpng==1.6.37=h21135ba_2
#     - conda-forge/linux-64::libuv==1.42.0=h7f98852_0
#     - conda-forge/linux-64::lz4-c==1.9.3=h9c3ff4c_1
#     - conda-forge/linux-64::mkl-service==2.4.0=py38h497a2fe_0
#     - conda-forge/linux-64::mkl_random==1.2.2=py38h1abd341_0
#     - conda-forge/linux-64::nettle==3.6=he412f7d_0
#     - conda-forge/linux-64::ninja==1.10.2=h4bd325d_0
#     - conda-forge/linux-64::openh264==2.1.1=h780b84a_0
#     - conda-forge/linux-64::python_abi==3.8=2_cp38
#     - conda-forge/linux-64::zstd==1.4.9=ha95c52a_0
#     - conda-forge/noarch::olefile==0.46=pyh9f0ad1d_1
#     - conda-forge/noarch::six==1.16.0=pyh6c4a22f_0
#     - conda-forge/noarch::typing_extensions==3.10.0.2=pyha770c72_0
#     - pkgs/main/linux-64::_libgcc_mutex==0.1=main
#     - pkgs/main/linux-64::_openmp_mutex==4.5=1_gnu
#     - pkgs/main/linux-64::blas==1.0=mkl
#     - pkgs/main/linux-64::intel-openmp==2021.3.0=h06a4308_3350
#     - pkgs/main/linux-64::jpeg==9b=h024ee3a_2
#     - pkgs/main/linux-64::lcms2==2.12=h3be6417_0
#     - pkgs/main/linux-64::ld_impl_linux-64==2.35.1=h7274673_9
#     - pkgs/main/linux-64::libffi==3.3=he6710b0_2
#     - pkgs/main/linux-64::libgcc-ng==9.3.0=h5101ec6_17
#     - pkgs/main/linux-64::libgomp==9.3.0=h5101ec6_17
#     - pkgs/main/linux-64::libstdcxx-ng==9.3.0=hd4cf53a_17
#     - pkgs/main/linux-64::libtiff==4.1.0=h2733197_1
#     - pkgs/main/linux-64::libwebp==1.2.0=h89dd481_0
#     - pkgs/main/linux-64::mkl==2021.3.0=h06a4308_520
#     - pkgs/main/linux-64::mkl_fft==1.3.0=py38h42c9631_2
#     - pkgs/main/linux-64::ncurses==6.2=he6710b0_1
#     - pkgs/main/linux-64::numpy-base==1.20.3=py38h74d4b33_0
#     - pkgs/main/linux-64::numpy==1.20.3=py38hf144106_0
#     - pkgs/main/linux-64::openssl==1.1.1l=h7f8727e_0
#     - pkgs/main/linux-64::pillow==8.3.1=py38h5aabda8_0
#     - pkgs/main/linux-64::pip==21.2.4=py38h06a4308_0
#     - pkgs/main/linux-64::python==3.8.11=h12debd9_0_cpython
#     - pkgs/main/linux-64::readline==8.1=h27cfd23_0
#     - pkgs/main/linux-64::setuptools==58.0.4=py38h06a4308_0
#     - pkgs/main/linux-64::sqlite==3.36.0=hc218d9a_0
#     - pkgs/main/linux-64::tk==8.6.11=h1ccaba5_0
#     - pkgs/main/linux-64::xz==5.2.5=h7b6447c_0
#     - pkgs/main/linux-64::zlib==1.2.11=h7b6447c_3
#     - pkgs/main/noarch::wheel==0.37.0=pyhd3eb1b0_1
#     - pytorch/linux-64::ffmpeg==4.3=hf484d3e_0
#     - pytorch/linux-64::pytorch==1.8.0=py3.8_cuda11.1_cudnn8.0.5_0
#     - pytorch/linux-64::torchaudio==0.8.0=py38
#     - pytorch/linux-64::torchvision==0.9.0=py38_cu111
#
#
# The following NEW packages will be INSTALLED:
#
#   _libgcc_mutex      pkgs/main/linux-64::_libgcc_mutex-0.1-main
#   _openmp_mutex      pkgs/main/linux-64::_openmp_mutex-4.5-1_gnu
#   blas               pkgs/main/linux-64::blas-1.0-mkl
#   bzip2              conda-forge/linux-64::bzip2-1.0.8-h7f98852_4
#   ca-certificates    conda-forge/linux-64::ca-certificates-2021.10.8-ha878542_0
#   certifi            conda-forge/linux-64::certifi-2021.10.8-py38h578d9bd_0
#   cudatoolkit        conda-forge/linux-64::cudatoolkit-11.1.1-h6406543_8
#   ffmpeg             pytorch/linux-64::ffmpeg-4.3-hf484d3e_0
#   freetype           conda-forge/linux-64::freetype-2.10.4-h0708190_1
#   giflib             conda-forge/linux-64::giflib-5.2.1-h36c2ea0_2
#   gmp                conda-forge/linux-64::gmp-6.2.1-h58526e2_0
#   gnutls             conda-forge/linux-64::gnutls-3.6.13-h85f3911_1
#   intel-openmp       pkgs/main/linux-64::intel-openmp-2021.3.0-h06a4308_3350
#   jpeg               pkgs/main/linux-64::jpeg-9b-h024ee3a_2
#   lame               conda-forge/linux-64::lame-3.100-h7f98852_1001
#   lcms2              pkgs/main/linux-64::lcms2-2.12-h3be6417_0
#   ld_impl_linux-64   pkgs/main/linux-64::ld_impl_linux-64-2.35.1-h7274673_9
#   libffi             pkgs/main/linux-64::libffi-3.3-he6710b0_2
#   libgcc-ng          pkgs/main/linux-64::libgcc-ng-9.3.0-h5101ec6_17
#   libgomp            pkgs/main/linux-64::libgomp-9.3.0-h5101ec6_17
#   libiconv           conda-forge/linux-64::libiconv-1.16-h516909a_0
#   libpng             conda-forge/linux-64::libpng-1.6.37-h21135ba_2
#   libstdcxx-ng       pkgs/main/linux-64::libstdcxx-ng-9.3.0-hd4cf53a_17
#   libtiff            pkgs/main/linux-64::libtiff-4.1.0-h2733197_1
#   libuv              conda-forge/linux-64::libuv-1.42.0-h7f98852_0
#   libwebp            pkgs/main/linux-64::libwebp-1.2.0-h89dd481_0
#   lz4-c              conda-forge/linux-64::lz4-c-1.9.3-h9c3ff4c_1
#   mkl                pkgs/main/linux-64::mkl-2021.3.0-h06a4308_520
#   mkl-service        conda-forge/linux-64::mkl-service-2.4.0-py38h497a2fe_0
#   mkl_fft            pkgs/main/linux-64::mkl_fft-1.3.0-py38h42c9631_2
#   mkl_random         conda-forge/linux-64::mkl_random-1.2.2-py38h1abd341_0
#   ncurses            pkgs/main/linux-64::ncurses-6.2-he6710b0_1
#   nettle             conda-forge/linux-64::nettle-3.6-he412f7d_0
#   ninja              conda-forge/linux-64::ninja-1.10.2-h4bd325d_0
#   numpy              pkgs/main/linux-64::numpy-1.20.3-py38hf144106_0
#   numpy-base         pkgs/main/linux-64::numpy-base-1.20.3-py38h74d4b33_0
#   olefile            conda-forge/noarch::olefile-0.46-pyh9f0ad1d_1
#   openh264           conda-forge/linux-64::openh264-2.1.1-h780b84a_0
#   openssl            pkgs/main/linux-64::openssl-1.1.1l-h7f8727e_0
#   pillow             pkgs/main/linux-64::pillow-8.3.1-py38h5aabda8_0
#   pip                pkgs/main/linux-64::pip-21.2.4-py38h06a4308_0
#   python             pkgs/main/linux-64::python-3.8.11-h12debd9_0_cpython
#   python_abi         conda-forge/linux-64::python_abi-3.8-2_cp38
#   pytorch            pytorch/linux-64::pytorch-1.8.0-py3.8_cuda11.1_cudnn8.0.5_0
#   readline           pkgs/main/linux-64::readline-8.1-h27cfd23_0
#   setuptools         pkgs/main/linux-64::setuptools-58.0.4-py38h06a4308_0
#   six                conda-forge/noarch::six-1.16.0-pyh6c4a22f_0
#   sqlite             pkgs/main/linux-64::sqlite-3.36.0-hc218d9a_0
#   tk                 pkgs/main/linux-64::tk-8.6.11-h1ccaba5_0
#   torchaudio         pytorch/linux-64::torchaudio-0.8.0-py38
#   torchvision        pytorch/linux-64::torchvision-0.9.0-py38_cu111
#   typing_extensions  conda-forge/noarch::typing_extensions-3.10.0.2-pyha770c72_0
#   wheel              pkgs/main/noarch::wheel-0.37.0-pyhd3eb1b0_1
#   xz                 pkgs/main/linux-64::xz-5.2.5-h7b6447c_0
#   zlib               pkgs/main/linux-64::zlib-1.2.11-h7b6447c_3
#   zstd               conda-forge/linux-64::zstd-1.4.9-ha95c52a_0
#
#
#
# Downloading and Extracting Packages:
#
# done
# done
# - By downloading and using the CUDA Toolkit conda packages, you accept the terms and conditions of the CUDA End User License Agreement (EULA): https://docs.nvidia.com/cuda/eula/index.html
#
# done
# #
# # To activate this environment, use
# #
# #     $ conda activate env
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate

# %%
# !pwd
# Out:
# /content/BRIO

# %%
# Create workspace directories
import os
os.makedirs('./cache', exist_ok=True)
os.makedirs('./result', exist_ok=True)

print(f'Working directory: {os.getcwd()}')
print(f'Contents: {os.listdir(".")}')
# Out:
# Working directory: /content/BRIO
# Contents: ['cnndm', 'cal_rouge.py', 'modeling_pegasus.py', '.gitignore', 'data_utils.py', 'main.ipynb', '.git', 'output', 'README.md', 'examples', 'main.py', 'model.png', 'cache', 'result', 'modeling_bart.py', 'compare-mt', 'gen_candidate.py', 'cnndm.zip', 'label_smoothing_loss.py', 'condacolab_install.log', 'utils.py', 'spec-file.txt', 'config.py', 'requirements.txt', 'preprocess.py', 'model.py']

# %% [markdown]
# ---
# ## 2. Data Preparation
#
# BRIO uses the **CNN/DailyMail** dataset. The authors provide preprocessed data that includes:
# - Source articles & reference summaries
# - Candidate summaries generated via diverse beam search
# - ROUGE scores for each candidate
#
# ### Option A: Download Full Preprocessed CNNDM Data (Recommended)
# Download from the authors' shared link and unzip into the root directory.

# %%
# Download preprocessed CNNDM data (lowercase/uncased version)
# This file is ~1GB and contains train/val/test splits with candidate summaries
# NOTE: If the link is expired, see Option B below or visit the GitHub README for updated links

# You can download manually from:
# https://yaleedu-my.sharepoint.com/:u:/g/personal/yixin_liu_yale_edu/EZAVS548ctlIt1dpVs0No6UBkGqMbS8CuMrWQ3ZcsPoyOA?e=deC4kz
# Then upload to Colab and unzip:

# --- Option 1: If you uploaded the zip file to Colab ---
# !unzip cnndm.zip -d .

# --- Option 2: If you have it on Google Drive ---
# from google.colab import drive
# drive.mount('/content/drive')
# !cp /content/drive/MyDrive/path/to/cnndm.zip .
# !unzip cnndm.zip -d .

# print("After unzipping, verify the data structure:")
# print("Expected: ./cnndm/diverse/train/ , ./cnndm/diverse/val/ , ./cnndm/diverse/test/")

# %%
# %%bash
# source activate env python preprocess.py --src_dir [path of the raw data] --tgt_dir [output path] --split [train/val/test] --cand_num [number of candidate summaries] --dataset [cnndm/xsum/nyt] -l [lowercase if the flag is set]

# %%
# Verify data structure
for split in ['train', 'val', 'test']:
    path = f'./cnndm/diverse/{split}'
    if os.path.exists(path):
        n_files = len(os.listdir(path))
        print(f'{split}: {n_files} files')
    else:
        print(f'{split}: NOT FOUND at {path}')

# Check for source/target files (needed for evaluation)
for f in ['test.source', 'test.target']:
    path = f'./cnndm/{f}'
    if os.path.exists(path):
        with open(path) as fp:
            n_lines = sum(1 for _ in fp)
        print(f'{f}: {n_lines} lines')
    else:
        print(f'{f}: NOT FOUND')
# Out:
# train: 287227 files
# val: 13368 files
# test: 11490 files
# test.source: NOT FOUND
# test.target: NOT FOUND

# %%
# Inspect a sample data point
import json

sample_path = './cnndm/diverse/test/0.json'
if os.path.exists(sample_path):
    with open(sample_path) as f:
        sample = json.load(f)

    print('=== Sample Data Structure ===')
    print(f'Keys: {list(sample.keys())}')
    print(f'\nArticle (first 2 sentences):')
    for s in sample['article_untok'][:2]:
        print(f'  {s}')
    print(f'\nAbstract (reference summary):')
    for s in sample['abstract_untok']:
        print(f'  {s}')
    print(f'\nNumber of candidates: {len(sample["candidates_untok"])}')
    print(f'Top candidate ROUGE score: {sample["candidates_untok"][0][1]:.4f}')
    print(f'Top candidate text: {" ".join(sample["candidates_untok"][0][0])[:200]}...')
else:
    print(f'Sample file not found. Make sure you downloaded and extracted the data.')

# %% [markdown]
# ### Option B: Use Example Raw Data (Small-Scale Demo)
#
# If you cannot download the full preprocessed data, you can use the small example files provided in `./examples/raw_data/` to go through the candidate generation and preprocessing steps. This is useful for understanding the pipeline but not for real training.

# %% [markdown]
# ---
# ## 3. Generate Candidate Summaries
#
# This step generates **16 diverse candidate summaries** per article using diverse beam search from a pretrained BART model. The candidates will later be scored and used for contrastive training.
#
# > **Note:** If you downloaded the preprocessed data (Option A), candidates are already included and you can **skip this section**. This section is needed only if you're processing your own data.

# %%
# Generate candidates from example raw data (small demo)
# This uses facebook/bart-large-cnn to generate 16 candidates per article
# For CNNDM dataset:

# !python gen_candidate.py \
    --gpuid 0 \
    --src_dir ./examples/raw_data/test.source \
    --tgt_dir ./examples/raw_data/test.out \
    --dataset cnndm

# %%
# Verify generated candidates
if os.path.exists('./examples/raw_data/test.out'):
    with open('./examples/raw_data/test.out') as f:
        lines = f.readlines()
    with open('./examples/raw_data/test.source') as f:
        n_articles = sum(1 for _ in f)
    print(f'Number of source articles: {n_articles}')
    print(f'Total candidate lines: {len(lines)}')
    print(f'Candidates per article: {len(lines) // n_articles}')
    print(f'\nFirst candidate:')
    print(f'  {lines[0].strip()[:200]}...')
else:
    print('Candidate file not generated yet. Run the cell above first.')

# %% [markdown]
# ---
# ## 4. Preprocess Data
#
# Preprocessing converts the raw data (source articles, reference summaries, candidate summaries) into per-sample JSON files. Each JSON contains:
# - `article` / `article_untok` – tokenized & untokenized article sentences
# - `abstract` / `abstract_untok` – reference summary
# - `candidates` / `candidates_untok` – list of (candidate, ROUGE_score) pairs
#
# > **Note:** If you downloaded the preprocessed data (Option A), skip this section.

# %%
# Preprocess the example data
# This computes ROUGE scores for each candidate and creates JSON files

# Create output directory
# !mkdir -p ./cnndm/diverse/test

# Run preprocessing
# !python preprocess.py \
    --src_dir ./examples/raw_data \
    --tgt_dir ./cnndm/diverse \
    --split test \
    --cand_num 16 \
    --dataset cnndm \
    -l

# Copy source and target files to the data folder (required for evaluation)
# !cp ./examples/raw_data/test.source ./cnndm/diverse/test.source
# !cp ./examples/raw_data/test.target ./cnndm/diverse/test.target
# !cp ./examples/raw_data/test.source ./cnndm/test.source
# !cp ./examples/raw_data/test.target ./cnndm/test.target

# %%
# Verify preprocessed data
test_dir = './cnndm/diverse/test'
if os.path.exists(test_dir):
    files = os.listdir(test_dir)
    print(f'Preprocessed test files: {len(files)}')

    # Inspect one preprocessed sample
    with open(os.path.join(test_dir, '0.json')) as f:
        sample = json.load(f)
    print(f'\nSample keys: {list(sample.keys())}')
    print(f'Number of candidates: {len(sample["candidates"])}')
    print(f'Candidate ROUGE scores: {[round(c[1], 4) for c in sample["candidates"][:5]]}...')
else:
    print('Preprocessed directory not found. Run preprocessing first.')

# %% [markdown]
# ---
# ## 5. Training
#
# BRIO training uses a **dual loss**:
# - **MLE Loss**: Standard cross-entropy on the gold summary (generation quality)
# - **Ranking Loss**: Contrastive margin loss ensuring the model assigns higher probability to better candidates
#
# ### Key Hyperparameters (CNNDM defaults)
# | Parameter | Value | Description |
# |-----------|-------|-------------|
# | `batch_size` | 1 | Per-GPU batch size |
# | `accumulate_step` | 8 | Gradient accumulation steps |
# | `mle_weight` | 0.1 | Weight for MLE loss |
# | `rank_weight` | 10 | Weight for ranking loss |
# | `max_lr` | 2e-3 | Peak learning rate |
# | `warmup_steps` | 10000 | LR warmup steps |
# | `eval_interval` | 1000 | Steps between evaluations |
# | `max_num` | 16 | Number of candidate summaries |
# | `model_type` | `facebook/bart-large-cnn` | Base model |
#
# > **⚠️ Training Time**: Full CNNDM training (287K samples) takes **many hours** even on a V100/A100. For a quick sanity check, reduce `eval_interval` or use a small data subset.

# %%
# Full training on CNNDM (single GPU)
# This will save checkpoints to ./cache/<date>-<id>/
# Saves: model_ranking.bin (best scorer), model_generation.bin (best generator), model_cur.bin (latest)

# !python main.py \
    --cuda \
    --gpuid 0 \
    --config cnndm \
    -l

# %%
# (Alternative) Resume training from an existing checkpoint
# Replace <checkpoint_folder>/model_cur.bin with your actual checkpoint path
# The path is relative to ./cache/ (do NOT include ./cache/ prefix)

# !python main.py \
#     --cuda \
#     --gpuid 0 \
#     --config cnndm \
#     -l \
#     --model_pt <checkpoint_folder>/model_cur.bin

# %%
# List saved checkpoints
cache_dir = './cache'
if os.path.exists(cache_dir):
    for d in sorted(os.listdir(cache_dir)):
        full_path = os.path.join(cache_dir, d)
        if os.path.isdir(full_path):
            files = os.listdir(full_path)
            print(f'{d}/')
            for f in files:
                size = os.path.getsize(os.path.join(full_path, f))
                print(f'  {f} ({size / 1024 / 1024:.1f} MB)' if size > 1024*1024 else f'  {f} ({size / 1024:.1f} KB)')
else:
    print('No checkpoints found. Train the model first.')

# %% [markdown]
# ---
# ## 6. Evaluation
#
# BRIO can be evaluated in two modes:
# - **Generator** (`-g`): Generate summaries using beam search and compute ROUGE
# - **Scorer/Reranker** (`-r`): Rerank candidate summaries by model likelihood and compute ROUGE
#
# ### Using Downloaded Checkpoints
# You can download pretrained checkpoints from the authors:
# - CNNDM Generation: [model_generation.bin](https://yaleedu-my.sharepoint.com/:u:/g/personal/yixin_liu_yale_edu/EWu_h8oUFKdKgv2r9GkTTlEBXRioWkd3Y51_HHN2zj9uUg?e=EFAnME)
# - CNNDM Ranking: [model_ranking.bin](https://yaleedu-my.sharepoint.com/:u:/g/personal/yixin_liu_yale_edu/EVLl9BXC8uhMttARDYehvbMBdG2u40wKR3ZeXuyIb4lVUQ?e=rVbYNs)
#
# Place them in `./cache/cnndm/` (create the folder if needed).

# %%
# Setup checkpoint folder for downloaded checkpoints
os.makedirs('./cache/cnndm', exist_ok=True)

# If you downloaded the checkpoints, upload them to Colab and copy:
# !cp /path/to/model_generation.bin ./cache/cnndm/
# !cp /path/to/model_ranking.bin ./cache/cnndm/

# Or from Google Drive:
# !cp /content/drive/MyDrive/path/to/model_generation.bin ./cache/cnndm/
# !cp /content/drive/MyDrive/path/to/model_ranking.bin ./cache/cnndm/

# %% [markdown]
# ### 6a. Evaluate as Generator
# Generate summaries from source articles using beam search, then compute ROUGE scores.

# %%
# Evaluate as generator
# This generates summaries and saves them to ./result/cnndm/test.out
# Replace 'cnndm/model_generation.bin' with your actual checkpoint path (relative to ./cache/)

# !python main.py \
    --cuda \
    --gpuid 0 \
    --config cnndm \
    -e \
    --model_pt cnndm/model_generation.bin \
    -g

# %%
# View some generated summaries
result_file = './result/cnndm/test.out'
if os.path.exists(result_file):
    with open(result_file) as f:
        summaries = f.readlines()
    print(f'Total generated summaries: {len(summaries)}')
    print('\n=== First 3 Generated Summaries ===')
    for i, s in enumerate(summaries[:3]):
        print(f'\n--- Summary {i+1} ---')
        print(s.strip()[:300])
else:
    print('No generated summaries found. Run evaluation first.')

# %% [markdown]
# ### 6b. Evaluate as Scorer/Reranker
# Use the model to rerank candidate summaries by their predicted likelihood.

# %%
# Evaluate as scorer/reranker
# This reranks candidates and saves results to ./result/cnndm/candidate_ranking/ and reference_ranking/

# !python main.py \
    --cuda \
    --gpuid 0 \
    --config cnndm \
    -e \
    --model_pt cnndm/model_ranking.bin \
    -r

# %% [markdown]
# ### 6c. Calculate ROUGE Scores
# Compute ROUGE-1, ROUGE-2, and ROUGE-L scores using the Python implementation.

# %%
# ROUGE for generator output (using Python implementation)
# -p flag uses compare-mt's Python ROUGE (no Perl ROUGE setup needed)
# -l flag lowercases the text before scoring

# First, create tokenized version using NLTK (simpler alternative to Stanford CoreNLP)
from nltk import word_tokenize, sent_tokenize

def tokenize_file(input_path, output_path):
    """Tokenize a file using NLTK word tokenizer."""
    with open(input_path) as fin, open(output_path, 'w') as fout:
        for line in fin:
            tokens = ' '.join(word_tokenize(line.strip()))
            fout.write(tokens + '\n')
    print(f'Tokenized: {input_path} -> {output_path}')

# Tokenize generated output and reference
if os.path.exists('./result/cnndm/test.out'):
    tokenize_file('./result/cnndm/test.out', './result/cnndm/test.out.tokenized')

if os.path.exists('./cnndm/test.target') and not os.path.exists('./cnndm/test.target.tokenized'):
    tokenize_file('./cnndm/test.target', './cnndm/test.target.tokenized')

# %%
# Calculate ROUGE scores for generator output
# !python cal_rouge.py \
    --ref ./cnndm/test.target.tokenized \
    --hyp ./result/cnndm/test.out.tokenized \
    -l -p

# %%
# Calculate ROUGE scores for reranker output
# (only available after running the scorer/reranker evaluation)

if os.path.exists('./result/cnndm/candidate_ranking') and os.path.exists('./result/cnndm/reference_ranking'):
    # !python cal_rouge.py \
        --ref ./result/cnndm/reference_ranking \
        --hyp ./result/cnndm/candidate_ranking \
        -l -p
else:
    print('Reranker output not found. Run scorer evaluation (6b) first.')

# %% [markdown]
# ---
# ## 7. Quick Demo: Use Pretrained BRIO from HuggingFace
#
# No data download or training needed — just load the pretrained model and generate summaries.
#
# Available models:
# - `Yale-LILY/brio-cnndm-uncased` (BART, CNNDM, lowercase)
# - `Yale-LILY/brio-cnndm-cased` (BART, CNNDM, cased)
# - `Yale-LILY/brio-xsum-cased` (Pegasus, XSum, cased)

# %%
from transformers import BartTokenizer, BartForConditionalGeneration

# Load pretrained BRIO (CNNDM, uncased)
model_name = 'Yale-LILY/brio-cnndm-uncased'
tokenizer = BartTokenizer.from_pretrained(model_name)
model = BartForConditionalGeneration.from_pretrained(model_name)
model.eval()

print(f'Model loaded: {model_name}')
print(f'Parameters: {sum(p.numel() for p in model.parameters()) / 1e6:.1f}M')

# %%
# Summarize a sample article
article = """
Manchester United superstar Cristiano Ronaldo scored his 806th career goal in Old Trafford,
breaking FIFA's all-time record for most goals in competitive matches in men's football history.
It was the second of three goals the Portuguese attacker scored during the game,
leading United to a 3-2 victory over Tottenham and finishing the day with 807 total career goals.
The previous FIFA goal record was held by Josef Bican, with 805 goals.
""".strip().lower()  # lowercase for uncased model

inputs = tokenizer([article], max_length=1024, return_tensors='pt', truncation=True)

import torch
with torch.no_grad():
    summary_ids = model.generate(
        inputs['input_ids'],
        max_length=140,
        min_length=55,
        num_beams=4,
        length_penalty=2.0,
        no_repeat_ngram_size=3,
        early_stopping=True,
    )

summary = tokenizer.decode(summary_ids[0], skip_special_tokens=True, clean_up_tokenization_spaces=False)
print('=== Article ===')
print(article)
print('\n=== Generated Summary ===')
print(summary)

# %%
# Try with your own article!
your_article = """
PASTE YOUR ARTICLE TEXT HERE
""".strip().lower()

if your_article != 'paste your article text here':
    inputs = tokenizer([your_article], max_length=1024, return_tensors='pt', truncation=True)
    with torch.no_grad():
        summary_ids = model.generate(
            inputs['input_ids'],
            max_length=140,
            min_length=55,
            num_beams=4,
            length_penalty=2.0,
            no_repeat_ngram_size=3,
            early_stopping=True,
        )
    summary = tokenizer.decode(summary_ids[0], skip_special_tokens=True, clean_up_tokenization_spaces=False)
    print('=== Your Summary ===')
    print(summary)
else:
    print('Replace the placeholder text above with your article!')

# %% [markdown]
# ---
# ## Reference: Full Pipeline Summary
#
# ```
# ┌─────────────────────┐
# │  1. Raw Data        │  test.source, test.target
# │     (articles +     │
# │      references)    │
# └─────────┬───────────┘
#           │
#           ▼
# ┌─────────────────────┐
# │  2. gen_candidate   │  Diverse beam search → test.out (16 candidates/article)
# │     .py             │  Uses facebook/bart-large-cnn
# └─────────┬───────────┘
#           │
#           ▼
# ┌─────────────────────┐
# │  3. preprocess.py   │  Score candidates with ROUGE → JSON files
# │                     │  Each JSON: {article, abstract, candidates_with_scores}
# └─────────┬───────────┘
#           │
#           ▼
# ┌─────────────────────┐
# │  4. main.py (train) │  MLE loss + Ranking loss → model_generation.bin
# │                     │                           → model_ranking.bin
# └─────────┬───────────┘
#           │
#           ▼
# ┌─────────────────────┐
# │  5. main.py (eval)  │  -g: Generate summaries → ROUGE scores
# │                     │  -r: Rerank candidates  → ROUGE scores
# └─────────────────────┘
# ```
