# %%
# !pwd
# Out:
# Failed to connect to the remote Jupyter Server 'https://8080-m-s-kkb-usw3b2-3r0k46ypfqbja-b.us-west3-2.prod.colab.dev/'. Verify the server is running and reachable. (request to https://8080-m-s-kkb-usw3b2-3r0k46ypfqbja-b.us-west3-2.prod.colab.dev/api/sessions?1788920263389 failed, reason: read ECONNRESET).

# %%
import os

print(os.listdir("./"))
# Out:
# Failed to connect to the remote Jupyter Server 'https://8080-m-s-kkb-usw3b2-3r0k46ypfqbja-b.us-west3-2.prod.colab.dev/'. Verify the server is running and reachable. (request to https://8080-m-s-kkb-usw3b2-3r0k46ypfqbja-b.us-west3-2.prod.colab.dev/api/sessions?1788920263389 failed, reason: read ECONNRESET).
